# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import os

np.random.seed(1337)

dat_root = "../data/supporting-data-for-Xu-et-al.-2021-Weather-and-Forecasting"

# %%
dat_df = pd.read_csv(os.path.join(dat_root, 'train_global_fill_REA_na_wo_img_scaled.csv'))

# %%
dat_df.head()
# Out:
#    Unnamed: 0      name    year  month   day  hour       vs0   lat    lon  \
# 0           0  EP011982  1982.0    5.0  20.0   0.0 -1.031592  11.0 -104.8
# 1           1  EP011982  1982.0    5.0  20.0   6.0 -1.031592  11.2 -105.2
# 2           2  EP011982  1982.0    5.0  20.0  12.0 -1.031592  11.4 -105.6
# 3           3  EP011982  1982.0    5.0  20.0  18.0 -1.031592  11.6 -105.8
# 4           4  EP011982  1982.0    5.0  21.0   0.0 -0.856183  12.0 -106.0
#
#    pressure  ...  RHCN_t108  RHCN_t114  RHCN_t120                   dt  basin  \
# 0       NaN  ...        NaN        NaN        NaN  1982-05-20 00:00:00     EP
# 1       NaN  ...        NaN        NaN        NaN  1982-05-20 06:00:00     EP
# 2       NaN  ...        NaN        NaN        NaN  1982-05-20 12:00:00     EP
# 3       NaN  ...        NaN        NaN        NaN  1982-05-20 18:00:00     EP
# 4       NaN  ...        NaN        NaN        NaN  1982-05-21 00:00:00     EP
#
# ...

# %%
dat_opr = pd.read_csv(os.path.join(dat_root, "NOAA_operational_vars_global_wLabels_fill_na_Y2019.csv"))

# %%
dat_opr.head()
# Out:
#    Unnamed: 0      name  year  month  day  hour   vs0   lat    lon  pressure  \
# 0           1  AL902019  2019      5   19    12  20.0  24.0  292.0       NaN
# 1           2  AL902019  2019      5   19    18  20.0  25.8  294.1       NaN
# 2           6  AL012019  2019      5   20    18  35.0  28.6  291.3       NaN
# 3           7  AL902019  2019      5   20    18  25.0  28.2  291.3       NaN
# 4           8  AL012019  2019      5   21     6  35.0  29.8  291.0       NaN
#
#    ...  RHCN_t102  RHCN_t108  RHCN_t114  RHCN_t120                   dt  \
# 0  ...        NaN        NaN        NaN        NaN  2019-05-19 12:00:00
# 1  ...        NaN        NaN        NaN        NaN  2019-05-19 18:00:00
# 2  ...        NaN        NaN        NaN        NaN  2019-05-20 18:00:00
# 3  ...        NaN        NaN        NaN        NaN  2019-05-20 18:00:00
# 4  ...        NaN        NaN        NaN        NaN  2019-05-21 06:00:00
#
#    basin      dvs24   DELV-12  vs0_hurdart2  type
# ...

# %%
import netCDF4

nc = netCDF4.Dataset('../data/HURSAT/HURSAT_b1_v06_2016007N27285_ALEX_c20180912/2016007N27285.ALEX.2016.01.07.0300.32.GOE-13.037.hursat-b1.v06.nc')
nc.variables.keys()
# Out:
# dict_keys(['htime', 'lat', 'lon', 'fname', 'sid', 'NomDate', 'NomTime', 'sss', 'nchan', 'SubSatLat', 'SubSatLon', 'WindSpd', 'CentPrs', 'CentLat', 'CentLon', 'VZA', 'VSCHN', 'IRNIR', 'IRWVP', 'IRWIN', 'IRSPL', 'VSVAR', 'IRVAR', 'archer_lat', 'archer_lon', 'archer_combo_score', 'archer_ring_score', 'archer_weak_flag', 'eye_prob', 'eye_comp', 'rad_eye', 'rad_eye_con1', 'rad_eye_con2', 'eye_conf', 'rad_eyewall', 'bt_eye', 'bt_eyewall', 'odt84', 'vlat', 'vlon', 'var_icen', 'ang_icen', 'tavg_icen', 'tmin_icen', 'tmax_icen', 'tstd_icen', 'tnum_icen', 'var_acen', 'ang_acen', 'tavg_acen', 'tmin_acen', 'tmax_acen', 'tstd_acen', 'tnum_acen', 'var_vcen', 'ang_vcen', 'tavg_vcen', 'tmin_vcen', 'tmax_vcen', 'tstd_vcen', 'tnum_vcen'])
