# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import hurdat2parser as hd2

# %%
data_df = pd.read_csv('../data/HURDAT_CSV/hurdat2-1851-2021-041922.csv')
data_df.tail()
# Out:
#       atcf_code storm_name  year  month  day  hour  minute record_id  \
# 15952  AL212021      WANDA  2021     11    7     0       0       NaN
# 15953  AL212021      WANDA  2021     11    7     6       0       NaN
# 15954  AL212021      WANDA  2021     11    7    12       0       NaN
# 15955  AL212021      WANDA  2021     11    7    18       0       NaN
# 15956  AL212021      WANDA  2021     11    8     0       0       NaN
#
#       system_status  latitude  ...  delta_distance_y         x         y  \
# 15952            TS      37.4  ...         33.462881 -0.281588 -0.086831
# 15953            TS      38.1  ...         78.161630  0.104722  0.375922
# 15954            LO      39.2  ...        123.164880 -0.939624  0.335005
# 15955            LO      40.9  ...        190.835273 -0.011001  0.058231
# 15956            LO      43.2  ...        260.003855  0.101945 -0.697500
#
#        day_of_year  minute_of_day  jday     vpre  vpre_inverse_scaled  \
# ...
